# %%
#import all the stuff
import json
from pandas.io.json import json_normalize
import pandas as pd
import numpy as np

# %%
url = 'https://data.cdc.gov/resource/n8mc-b4w4.json'
df = pd.read_json(url)
print(df)
# Out:
#     case_month res_state  state_fips_code     res_county county_fips_code  \
# 0      2020-06        OH               39        BELMONT            39013
# 1      2020-09        OH               39         GALLIA            39053
# 2      2020-11        PA               42            ELK            42047
# 3      2021-02        AL                1     TALLAPOOSA            01123
# 4      2020-12        IA               19        CARROLL            19027
# ..         ...       ...              ...            ...              ...
# 995    2020-09        FL               12          PASCO            12101
# 996    2020-12        GA               13       PAULDING            13223
# 997    2020-09        VA               51  RICHMOND CITY            51760
# 998    2020-03        TX               48         HARRIS            48201
# 999    2020-03        TX               48          BEXAR            48029
#
#           age_group     sex     race        ethnicity  case_positive_specimen  \
# 0                NA      NA       NA               NA                     0.0
# 1      0 - 17 years      NA       NA               NA                     NaN
# 2    18 to 49 years      NA       NA               NA                     0.0
# 3           Missing  Female  Missing          Missing                     NaN
# 4      0 - 17 years  Female       NA               NA                     NaN
# ..              ...     ...      ...              ...                     ...
# 995  18 to 49 years  Female    White  Hispanic/Latino                     NaN
# 996  18 to 49 years  Female    White  Hispanic/Latino                     NaN
# 997  18 to 49 years  Female    White  Hispanic/Latino                     NaN
# 998  50 to 64 years  Female    White  Hispanic/Latino                     NaN
# 999       65+ years  Female    White  Hispanic/Latino                     NaN
#
#      process exposure_yn             current_status symptom_status  hosp_yn  \
# 0    Missing     Missing  Laboratory-confirmed case        Missing  Missing
# 1    Missing     Missing  Laboratory-confirmed case        Missing  Missing
# 2    Missing     Missing  Laboratory-confirmed case        Unknown       No
# 3    Missing     Missing              Probable Case        Missing  Missing
# 4    Missing     Missing              Probable Case    Symptomatic  Missing
# ..       ...         ...                        ...            ...      ...
# 995  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 996  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
# 997  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 998  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
# 999  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
#
#       icu_yn death_yn underlying_conditions_yn  case_onset_interval
# 0    Missing       NA                      Yes                  NaN
# 1    Missing       No                      NaN                  NaN
# 2    Unknown  Unknown                      NaN                  NaN
# 3    Missing  Missing                      NaN                  NaN
# 4    Missing  Missing                      NaN                  0.0
# ..       ...      ...                      ...                  ...
# 995  Missing       No                      NaN                  0.0
# 996  Missing  Missing                      NaN                  0.0
# 997  Missing       NA                      NaN                  0.0
# 998  Missing  Missing                      NaN                  0.0
# 999  Missing  Missing                      NaN                  0.0
#
# [1000 rows x 19 columns]

# %%
df
# Out:
#     case_month res_state  state_fips_code     res_county county_fips_code  \
# 0      2020-06        OH               39        BELMONT            39013
# 1      2020-09        OH               39         GALLIA            39053
# 2      2020-11        PA               42            ELK            42047
# 3      2021-02        AL                1     TALLAPOOSA            01123
# 4      2020-12        IA               19        CARROLL            19027
# ..         ...       ...              ...            ...              ...
# 995    2020-09        FL               12          PASCO            12101
# 996    2020-12        GA               13       PAULDING            13223
# 997    2020-09        VA               51  RICHMOND CITY            51760
# 998    2020-03        TX               48         HARRIS            48201
# 999    2020-03        TX               48          BEXAR            48029
#
#           age_group     sex     race        ethnicity  case_positive_specimen  \
# 0                NA      NA       NA               NA                     0.0
# 1      0 - 17 years      NA       NA               NA                     NaN
# 2    18 to 49 years      NA       NA               NA                     0.0
# 3           Missing  Female  Missing          Missing                     NaN
# 4      0 - 17 years  Female       NA               NA                     NaN
# ..              ...     ...      ...              ...                     ...
# 995  18 to 49 years  Female    White  Hispanic/Latino                     NaN
# 996  18 to 49 years  Female    White  Hispanic/Latino                     NaN
# 997  18 to 49 years  Female    White  Hispanic/Latino                     NaN
# 998  50 to 64 years  Female    White  Hispanic/Latino                     NaN
# 999       65+ years  Female    White  Hispanic/Latino                     NaN
#
#      process exposure_yn             current_status symptom_status  hosp_yn  \
# 0    Missing     Missing  Laboratory-confirmed case        Missing  Missing
# 1    Missing     Missing  Laboratory-confirmed case        Missing  Missing
# 2    Missing     Missing  Laboratory-confirmed case        Unknown       No
# 3    Missing     Missing              Probable Case        Missing  Missing
# 4    Missing     Missing              Probable Case    Symptomatic  Missing
# ..       ...         ...                        ...            ...      ...
# 995  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 996  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
# 997  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 998  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
# 999  Missing     Missing  Laboratory-confirmed case    Symptomatic  Missing
#
#       icu_yn death_yn underlying_conditions_yn  case_onset_interval
# 0    Missing       NA                      Yes                  NaN
# 1    Missing       No                      NaN                  NaN
# 2    Unknown  Unknown                      NaN                  NaN
# 3    Missing  Missing                      NaN                  NaN
# 4    Missing  Missing                      NaN                  0.0
# ..       ...      ...                      ...                  ...
# 995  Missing       No                      NaN                  0.0
# 996  Missing  Missing                      NaN                  0.0
# 997  Missing       NA                      NaN                  0.0
# 998  Missing  Missing                      NaN                  0.0
# 999  Missing  Missing                      NaN                  0.0
#
# [1000 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   case_month                1000 non-null   object
#  1   res_state                 1000 non-null   object
#  2   state_fips_code           1000 non-null   int64
#  3   res_county                1000 non-null   object
#  4   county_fips_code          1000 non-null   object
#  5   age_group                 1000 non-null   object
#  6   sex                       1000 non-null   object
#  7   race                      1000 non-null   object
#  8   ethnicity                 1000 non-null   object
#  9   case_positive_specimen    310 non-null    float64
#  10  process                   1000 non-null   object
#  11  exposure_yn               1000 non-null   object
#  12  current_status            1000 non-null   object
#  13  symptom_status            1000 non-null   object
#  14  hosp_yn                   1000 non-null   object
#  15  icu_yn                    1000 non-null   object
#  16  death_yn                  1000 non-null   object
#  17  underlying_conditions_yn  70 non-null     object
#  18  case_onset_interval       476 non-null    float64
# dtypes: float64(2), int64(1), object(16)
# memory usage: 148.6+ KB
