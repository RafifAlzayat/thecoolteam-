# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
# Loading the virignia covid data
file_path = "/Users/ava/Desktop/virginia_covid.csv"
df = pd.read_csv(file_path)
df = df.loc[:, columns].copy()

# %%
#creating pie chart to understand age group distribution for covid data
age_df = df["age_group"].value_counts()
age_plot = age_df.plot.pie(subplots=True, figsize=(11, 6))

# %%
#creating pie chart to understand race distribution for covid data
race_df = df["race"].value_counts()
race_plot = race_df.plot.pie(subplots=True, figsize=(11, 6))

# %%
#creating pie chart to understand sex distribution for covid data
sex_df = df["sex"].value_counts()
sex_plot = sex_df.plot.pie(subplots=True, figsize=(11, 6))

# %%
#creating pie chart to understand hospitalization distribution for covid data
hosp_df = df["hosp_yn"].value_counts()
hosp_plot = hosp_df.plot.pie(subplots=True, figsize=(11, 6))

# %%
#creating pie chart to understand ethniciy distribution for covid data
ethnicity_df = df["ethnicity"].value_counts()
ethnicity_plot = ethnicity_df.plot.pie(subplots=True, figsize=(11, 6))

# %%
#creating pie chart to understand county distribution for covid data
county_df = df["res_county"].value_counts()
county_plot = county_df.plot.pie(subplots=True, figsize=(11, 6))
